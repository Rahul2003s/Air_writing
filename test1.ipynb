# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_csv('test.csv')
df=pd.DataFrame(data)
df.iloc[:,2]
plt.plot(np.arange(0,100),df.iloc[:,0][df.iloc[:,3] == 2][:100], label='X-axis')
plt.plot(np.arange (0,100),df.iloc[:,1][df.iloc[:,3] == 2][:100], label='Y-axis')
plt.plot(np.arange (0,100),df.iloc[:,2][df.iloc[:,3] == 2][:100], label='Z-axis')
plt.title("Graph")
plt.legend()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.iloc[:,0],df.iloc[:,1],df.iloc[:,2])

# set axis labels and title
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('3D Scatter Plot')

# show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

X, Y = np.meshgrid(df.iloc[:,0], df.iloc[:,1])
Z = df.iloc[:,2]
# create a 3D surface plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X,Y,Z)

# set axis labels and title
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('3D Surface Plot')

# show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 9
#       7 fig = plt.figure()
#       8 ax = fig.add_subplot(111, projection='3d')
# ----> 9 ax.plot_surface(X,Y,Z)
#      11 # set axis labels and title
#      12 ax.set_xlabel('X Label')
#
# File /opt/homebrew/lib/python3.10/site-packages/mpl_toolkits/mplot3d/axes3d.py:1386, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, **kwargs)
#    1383 had_data = self.has_data()
#    1385 if Z.ndim != 2:
# -> 1386     raise ValueError("Argument Z must be 2-dimensional.")
#    1388 Z = cbook._to_unmasked_float_array(Z)
#    1389 X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# generate some data for plotting
t = np.linspace(0, 10, 100)
y = df.iloc[:,0]
z= df.iloc[:,1]
x  = df.iloc[:,2]

# create a 3D figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# plot the line
ax.plot(x, y, z)

# set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# show the plot
plt.show()
