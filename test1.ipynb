# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_csv('test.csv')
df=pd.DataFrame(data)
df.iloc[:,2]
plt.plot(np.arange(0,100),df.iloc[:,0][df.iloc[:,3] == 2][:100], label='X-axis')
plt.plot(np.arange (0,100),df.iloc[:,1][df.iloc[:,3] == 2][:100], label='Y-axis')
plt.plot(np.arange (0,100),df.iloc[:,2][df.iloc[:,3] == 2][:100], label='Z-axis')
plt.title("Graph")
plt.legend()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.iloc[:,0],df.iloc[:,1],df.iloc[:,2])

# set axis labels and title
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('3D Scatter Plot')

# show the plot
plt.show()

# %%
# generate some data for plotting
t = np.linspace(0, 10, 100)
x= df.iloc[:,0]
y = df.iloc[:,1]
z = df.iloc[:,2]

# create a 3D figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# plot the line
ax.plot(x, y, z)

# set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# accelerometer data
x = df.iloc[:,0]
y =df.iloc[:,1]
z =df.iloc[:,2]
# create a 3D figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# plot the data as a line
ax.plot(x, y, z)

# set labels for the axes
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

# display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# accelerometer data (x, y, z)
x = df.iloc[:,0]
y =df.iloc[:,1]
z =df.iloc[:,2]
# create a 3D figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# plot the data as a line
ax.plot(x, y, z)

# set labels for the axes
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

# set the limits for the axes
ax.set_xlim3d(min(x), max(x))
ax.set_ylim3d(min(y), max(y))
ax.set_zlim3d(min(z), max(z))

# display the plot
plt.show()

# %%
from scipy.io import loadmat
mat= loadmat('./source/matR_char/lower_b_C1_t02.mat')

# %%
mat.get('gest')
# Out:
# array([[ 1.6635000e+01,  3.3312000e+01,  4.9977001e+01, ...,
#          2.1338052e+03,  2.1505691e+03,  2.1671621e+03],
#        [-9.3507439e-02, -9.4521336e-02, -9.6502081e-02, ...,
#         -1.1635092e-01, -1.1412926e-01, -1.1054015e-01],
#        [ 3.3883387e-01,  3.3755636e-01,  3.3498430e-01, ...,
#         -8.4633797e-02, -8.0987394e-02, -7.7310532e-02],
#        ...,
#        [-7.5411893e-02, -1.2580041e-02,  1.0784768e-01, ...,
#         -6.4613461e-01, -7.5783569e-01, -8.6255544e-01],
#        [-7.0387030e-01, -6.4540178e-01, -5.8431524e-01, ...,
#          3.4158200e-01,  2.3598957e-01,  1.8450235e-01],
#        [ 2.4835575e-02,  2.3252976e-01,  3.5208479e-01, ...,
#         -1.8547663e-01, -2.1427456e-01, -2.8059706e-01]], dtype=float32)

# %%
import pandas as pd
df=pd.DataFrame(mat.get('gest'))

# %%
df
# Out:
#           0          1          2          3          4          5    \
# 0   16.635000  33.312000  49.977001  66.656006  83.319000  99.996002
# 1   -0.093507  -0.094521  -0.096502  -0.097590  -0.098769  -0.099475
# 2    0.338834   0.337556   0.334984   0.330672   0.324735   0.318081
# 3   -0.358847  -0.360573  -0.362903  -0.365154  -0.366761  -0.368418
# 4    0.936037   0.939275   0.940607   0.942588   0.943703   0.947676
# 5    0.344970   0.336399   0.332744   0.326829   0.323167   0.309816
# 6    0.066444   0.064712   0.063992   0.064369   0.065463   0.068361
# 7    0.020370   0.020253   0.021088   0.023803   0.026498   0.035371
# 8    0.125000  -0.000000  -0.000000   0.041667   0.083333   0.166667
# 9    0.461538   0.500000   0.461538   0.423077   0.423077   0.538462
# 10  -0.440000  -0.360000  -0.360000  -0.320000  -0.360000  -0.360000
# 11  -0.075412  -0.012580   0.107848   0.277145   0.296343   0.246601
# 12  -0.703870  -0.645402  -0.584315  -0.831279  -1.038974  -1.324335
# ...

# %%
df.shape
# Out:
# (14, 153)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Create the figure and the axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Define the data for the line plot
# accelerometer data (x, y, z)
x = df.iloc[:,0]
y =df.iloc[:,1]
z =df.iloc[:,2]

# Plot the line
ax.plot(x, y, z)

# Set the labels and the ticks for the x-axis
ax.xaxis.set_label_position('top')
ax.set_xlabel('X Label')
# ax.set_xticks([0, 0.25, 0.5, 0.75, 1])

# Set the labels and the ticks for the y-axis
# ax.yaxis.set_label_position('left')
ax.set_ylabel('Y Label')
# ax.set_yticks([0, 0.25, 0.5, 0.75, 1])

# Set the labels and the ticks for the z-axis
ax.zaxis.set_label_position('bottom')
ax.set_zlabel('Z Label')
# ax.set_zticks([-1, -0.5, 0, 0.5, 1])

# Set the title
ax.set_title('3D Line Plot with X on Top, Y on Left, and Z on Bottom')
ax.invert_xaxis()
# Show the plot
plt.show()
